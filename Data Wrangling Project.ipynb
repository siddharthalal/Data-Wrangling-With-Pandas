# %%
import pandas as pd
import numpy as np

# %%
df =pd.read_csv('https://raw.githubusercontent.com/jackiekazil/data-wrangling/master/data/chp3/data-text.csv')
df.head(2)
# Out:
#                           Indicator PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# ### 1. Get the Metadata from the above file.

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4656 entries, 0 to 4655
# Data columns (total 12 columns):
# Indicator                  4656 non-null object
# PUBLISH STATES             4656 non-null object
# Year                       4656 non-null int64
# WHO region                 4656 non-null object
# World Bank income group    4656 non-null object
# Country                    4656 non-null object
# Sex                        4656 non-null object
# Display Value              4656 non-null int64
# Numeric                    4656 non-null float64
# Low                        0 non-null float64
# High                       0 non-null float64
# Comments                   0 non-null float64
# dtypes: float64(4), int64(2), object(6)
# memory usage: 436.6+ KB
# None

# %% [markdown]
# ### 2. Get the row names from the above file.

# %%
df.index.values
# Out:
# array([   0,    1,    2, ..., 4653, 4654, 4655], dtype=int64)

# %% [markdown]
# ### 3.Change any column name.

# %%
df.rename(columns={'Indicator': 'Indicator_id'}).head()
# Out:
#                         Indicator_id PUBLISH STATES  Year  \
# 0   Life expectancy at birth (years)      Published  1990
# 1   Life expectancy at birth (years)      Published  2000
# 2  Life expectancy at age 60 (years)      Published  2012
# 3  Life expectancy at age 60 (years)      Published  2000
# 4   Life expectancy at birth (years)      Published  2012
#
#               WHO region World Bank income group               Country  \
# 0                 Europe             High-income               Andorra
# 1                 Europe             High-income               Andorra
# 2                 Europe             High-income               Andorra
# 3                 Europe             High-income               Andorra
# 4  Eastern Mediterranean             High-income  United Arab Emirates
#
#           Sex  Display Value  Numeric  Low  High  Comments
# 0  Both sexes             77     77.0  NaN   NaN       NaN
# 1  Both sexes             80     80.0  NaN   NaN       NaN
# 2      Female             28     28.0  NaN   NaN       NaN
# 3  Both sexes             23     23.0  NaN   NaN       NaN
# 4      Female             78     78.0  NaN   NaN       NaN

# %% [markdown]
# ### 4. Change any column name and store the changes made permanently.

# %%
df = df.rename(columns={'Indicator': 'Indicator_id'})
df.head(2)
# Out:
#                        Indicator_id PUBLISH STATES  Year WHO region  \
# 0  Life expectancy at birth (years)      Published  1990     Europe
# 1  Life expectancy at birth (years)      Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# ### 5. Change the name of multiple columns.

# %%
df = df.rename(columns={'PUBLISH STATES': 'Publication Status', 'WHO region': 'WHO Region'})

df.head(2)
# Out:
#                        Indicator_id Publication Status  Year WHO Region  \
# 0  Life expectancy at birth (years)          Published  1990     Europe
# 1  Life expectancy at birth (years)          Published  2000     Europe
#
#   World Bank income group  Country         Sex  Display Value  Numeric  Low  \
# 0             High-income  Andorra  Both sexes             77     77.0  NaN
# 1             High-income  Andorra  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# ### 6. Arrange values of a particular column in ascending order ###

# %%
df.sort_values(by=['Year'], ascending=True).head(5)
# Out:
#                            Indicator_id Publication Status  Year WHO Region  \
# 0      Life expectancy at birth (years)          Published  1990     Europe
# 1270   Life expectancy at birth (years)          Published  1990     Europe
# 3193   Life expectancy at birth (years)          Published  1990     Europe
# 3194   Life expectancy at birth (years)          Published  1990     Europe
# 3197  Life expectancy at age 60 (years)          Published  1990     Europe
#
#      World Bank income group              Country         Sex  Display Value  \
# 0                High-income              Andorra  Both sexes             77
# 1270             High-income              Germany        Male             72
# 3193     Lower-middle-income  Republic of Moldova        Male             65
# 3194     Lower-middle-income  Republic of Moldova  Both sexes             68
# 3197     Lower-middle-income  Republic of Moldova        Male             15
#
#       Numeric  Low  High  Comments
# 0        77.0  NaN   NaN       NaN
# 1270     72.0  NaN   NaN       NaN
# 3193     65.0  NaN   NaN       NaN
# 3194     68.0  NaN   NaN       NaN
# 3197     15.0  NaN   NaN       NaN

# %% [markdown]
# ### 7. Arrange multiple column values in ascending order ###

# %%
df.sort_values(by=['WHO Region', 'Country', 'Indicator_id', 'Publication Status']).head(3)
# Out:
#                                          Indicator_id Publication Status  \
# 3408  Healthy life expectancy (HALE) at birth (years)          Published
# 3409  Healthy life expectancy (HALE) at birth (years)          Published
# 3734  Healthy life expectancy (HALE) at birth (years)          Published
#
#       Year WHO Region World Bank income group  Country         Sex  \
# 3408  2000     Africa     Upper-middle-income  Algeria  Both sexes
# 3409  2012     Africa     Upper-middle-income  Algeria        Male
# 3734  2000     Africa     Upper-middle-income  Algeria        Male
#
#       Display Value  Numeric  Low  High  Comments
# 3408             60     60.0  NaN   NaN       NaN
# 3409             62     62.0  NaN   NaN       NaN
# 3734             59     59.0  NaN   NaN       NaN

# %% [markdown]
# ### 8. Make country as the first column of the data frame ###

# %%
df = df.reindex(['Country', 'Indicator_id', 'Publication Status', 'Year',
 'WHO Region',
 'World Bank income group',
 'Sex',
 'Display Value',
 'Numeric',
 'Low',
 'High',
 'Comments'], axis=1)

df.head(2)
# Out:
#    Country                      Indicator_id Publication Status  Year  \
# 0  Andorra  Life expectancy at birth (years)          Published  1990
# 1  Andorra  Life expectancy at birth (years)          Published  2000
#
#   WHO Region World Bank income group         Sex  Display Value  Numeric  Low  \
# 0     Europe             High-income  Both sexes             77     77.0  NaN
# 1     Europe             High-income  Both sexes             80     80.0  NaN
#
#    High  Comments
# 0   NaN       NaN
# 1   NaN       NaN

# %% [markdown]
# ### 9. Get the column array using a variable ###

# %%
array_region = df["WHO Region"].values

array_region
# Out:
# array(['Europe', 'Europe', 'Europe', ..., 'Africa', 'Africa', 'Africa'],
#       dtype=object)

# %% [markdown]
# ### 10. Get the subset rows 11, 24, 37 ###

# %%
df.loc[[11, 24, 37], :]
# Out:
#               Country                       Indicator_id Publication Status  \
# 11            Austria   Life expectancy at birth (years)          Published
# 24  Brunei Darussalam  Life expectancy at age 60 (years)          Published
# 37             Cyprus  Life expectancy at age 60 (years)          Published
#
#     Year       WHO Region World Bank income group     Sex  Display Value  \
# 11  2012           Europe             High-income  Female             83
# 24  2012  Western Pacific             High-income  Female             21
# 37  2012           Europe             High-income  Female             26
#
#     Numeric  Low  High  Comments
# 11     83.0  NaN   NaN       NaN
# 24     21.0  NaN   NaN       NaN
# 37     26.0  NaN   NaN       NaN

# %% [markdown]
# ### 11. Get the subset rows excluding 5, 12, 23, 36

# %%
bad_df = df.index.isin([5, 12, 23, 56])

df[~bad_df].head(60)
# Out:
#                                               Country  \
# 0                                             Andorra
# 1                                             Andorra
# 2                                             Andorra
# 3                                             Andorra
# 4                                United Arab Emirates
# 6                                 Antigua and Barbuda
# 7                                 Antigua and Barbuda
# 8                                           Australia
# 9                                           Australia
# 10                                          Australia
# 11                                            Austria
# 13                                            Belgium
# 14                                            Bahrain
# 15                                            Bahrain
# 16                                            Bahrain
# 17                                            Bahamas
# 18                                            Bahamas
# 19                                           Barbados
# 20                                           Barbados
# 21                                           Barbados
# 22                                  Brunei Darussalam
# 24                                  Brunei Darussalam
# 25                                             Canada
# 26                                             Canada
# 27                                             Canada
# 28                                        Switzerland
# 29                                        Switzerland
# 30                                        Switzerland
# 31                                       Cook Islands
# 32                                       Cook Islands
# 33                                       Cook Islands
# 34                                             Cyprus
# 35                                             Cyprus
# 36                                             Cyprus
# 37                                             Cyprus
# 38                                     Czech Republic
# 39                                     Czech Republic
# 40                                            Germany
# 41                                            Germany
# 42                                            Germany
# 43                                            Denmark
# 44                                            Denmark
# 45                                            Denmark
# 46                                            Denmark
# 47                                            Denmark
# 48                                              Spain
# 49                                              Spain
# 50                                              Spain
# 51                                            Estonia
# 52                                            Estonia
# 53                                            Estonia
# 54                                            Estonia
# 55                                            Estonia
# 57                                            Finland
# 58                                             France
# 59                                             France
# 60  United Kingdom of Great Britain and Northern I...
# 61  United Kingdom of Great Britain and Northern I...
# 62  United Kingdom of Great Britain and Northern I...
# 63                                  Equatorial Guinea
#
#                          Indicator_id Publication Status  Year  \
# 0    Life expectancy at birth (years)          Published  1990
# 1    Life expectancy at birth (years)          Published  2000
# 2   Life expectancy at age 60 (years)          Published  2012
# 3   Life expectancy at age 60 (years)          Published  2000
# 4    Life expectancy at birth (years)          Published  2012
# 6   Life expectancy at age 60 (years)          Published  1990
# 7   Life expectancy at age 60 (years)          Published  2012
# 8    Life expectancy at birth (years)          Published  2012
# 9    Life expectancy at birth (years)          Published  2000
# 10   Life expectancy at birth (years)          Published  2012
# 11   Life expectancy at birth (years)          Published  2012
# 13   Life expectancy at birth (years)          Published  2012
# 14   Life expectancy at birth (years)          Published  2000
# 15   Life expectancy at birth (years)          Published  1990
# 16  Life expectancy at age 60 (years)          Published  1990
# 17   Life expectancy at birth (years)          Published  2012
# 18  Life expectancy at age 60 (years)          Published  2000
# 19   Life expectancy at birth (years)          Published  1990
# 20  Life expectancy at age 60 (years)          Published  2012
# 21  Life expectancy at age 60 (years)          Published  2012
# 22  Life expectancy at age 60 (years)          Published  1990
# 24  Life expectancy at age 60 (years)          Published  2012
# 25   Life expectancy at birth (years)          Published  2000
# 26  Life expectancy at age 60 (years)          Published  2000
# 27  Life expectancy at age 60 (years)          Published  1990
# 28   Life expectancy at birth (years)          Published  1990
# 29   Life expectancy at birth (years)          Published  2012
# 30  Life expectancy at age 60 (years)          Published  2000
# 31   Life expectancy at birth (years)          Published  2012
# 32  Life expectancy at age 60 (years)          Published  2012
# 33  Life expectancy at age 60 (years)          Published  2000
# 34   Life expectancy at birth (years)          Published  2000
# 35   Life expectancy at birth (years)          Published  2000
# 36  Life expectancy at age 60 (years)          Published  2000
# 37  Life expectancy at age 60 (years)          Published  2012
# 38   Life expectancy at birth (years)          Published  2012
# 39   Life expectancy at birth (years)          Published  1990
# 40   Life expectancy at birth (years)          Published  1990
# 41  Life expectancy at age 60 (years)          Published  1990
# 42  Life expectancy at age 60 (years)          Published  2000
# 43   Life expectancy at birth (years)          Published  2012
# 44  Life expectancy at age 60 (years)          Published  1990
# 45  Life expectancy at age 60 (years)          Published  2000
# 46  Life expectancy at age 60 (years)          Published  2000
# 47  Life expectancy at age 60 (years)          Published  2012
# 48   Life expectancy at birth (years)          Published  2012
# 49  Life expectancy at age 60 (years)          Published  2000
# 50  Life expectancy at age 60 (years)          Published  1990
# 51   Life expectancy at birth (years)          Published  1990
# 52   Life expectancy at birth (years)          Published  2012
# 53  Life expectancy at age 60 (years)          Published  2012
# 54  Life expectancy at age 60 (years)          Published  2000
# 55  Life expectancy at age 60 (years)          Published  2012
# 57  Life expectancy at age 60 (years)          Published  2012
# 58   Life expectancy at birth (years)          Published  2000
# 59  Life expectancy at age 60 (years)          Published  2000
# 60   Life expectancy at birth (years)          Published  2012
# 61   Life expectancy at birth (years)          Published  2012
# 62  Life expectancy at age 60 (years)          Published  1990
# 63   Life expectancy at birth (years)          Published  2000
#
#                WHO Region World Bank income group         Sex  Display Value  \
# 0                  Europe             High-income  Both sexes             77
# 1                  Europe             High-income  Both sexes             80
# 2                  Europe             High-income      Female             28
# 3                  Europe             High-income  Both sexes             23
# 4   Eastern Mediterranean             High-income      Female             78
# 6                Americas             High-income        Male             17
# 7                Americas             High-income  Both sexes             22
# 8         Western Pacific             High-income        Male             81
# 9         Western Pacific             High-income  Both sexes             80
# 10        Western Pacific             High-income  Both sexes             83
# 11                 Europe             High-income      Female             83
# 13                 Europe             High-income      Female             83
# 14  Eastern Mediterranean             High-income        Male             73
# 15  Eastern Mediterranean             High-income      Female             74
# 16  Eastern Mediterranean             High-income        Male             17
# 17               Americas             High-income        Male             72
# 18               Americas             High-income  Both sexes             21
# 19               Americas             High-income        Male             71
# 20               Americas             High-income      Female             25
# 21               Americas             High-income  Both sexes             23
# 22        Western Pacific             High-income      Female             20
# 24        Western Pacific             High-income      Female             21
# 25               Americas             High-income      Female             82
# 26               Americas             High-income        Male             21
# 27               Americas             High-income      Female             24
# 28                 Europe             High-income        Male             74
# 29                 Europe             High-income  Both sexes             83
# 30                 Europe             High-income  Both sexes             23
# 31        Western Pacific             High-income  Both sexes             76
# 32        Western Pacific             High-income      Female             22
# 33        Western Pacific             High-income  Both sexes             18
# 34                 Europe             High-income      Female             79
# 35                 Europe             High-income  Both sexes             77
# 36                 Europe             High-income      Female             22
# 37                 Europe             High-income      Female             26
# 38                 Europe             High-income        Male             75
# 39                 Europe             High-income      Female             75
# 40                 Europe             High-income      Female             79
# 41                 Europe             High-income        Male             18
# 42                 Europe             High-income        Male             20
# 43                 Europe             High-income  Both sexes             80
# 44                 Europe             High-income        Male             18
# 45                 Europe             High-income        Male             19
# 46                 Europe             High-income  Both sexes             21
# 47                 Europe             High-income  Both sexes             23
# 48                 Europe             High-income  Both sexes             82
# 49                 Europe             High-income      Female             25
# 50                 Europe             High-income  Both sexes             22
# 51                 Europe             High-income      Female             75
# 52                 Europe             High-income      Female             81
# 53                 Europe             High-income        Male             18
# 54                 Europe             High-income      Female             21
# 55                 Europe             High-income      Female             24
# 57                 Europe             High-income        Male             22
# 58                 Europe             High-income        Male             75
# 59                 Europe             High-income        Male             20
# 60                 Europe             High-income      Female             83
# 61                 Europe             High-income  Both sexes             81
# 62                 Europe             High-income        Male             18
# 63                 Africa             High-income      Female             52
#
#     Numeric  Low  High  Comments
# 0      77.0  NaN   NaN       NaN
# 1      80.0  NaN   NaN       NaN
# 2      28.0  NaN   NaN       NaN
# 3      23.0  NaN   NaN       NaN
# 4      78.0  NaN   NaN       NaN
# 6      17.0  NaN   NaN       NaN
# 7      22.0  NaN   NaN       NaN
# 8      81.0  NaN   NaN       NaN
# 9      80.0  NaN   NaN       NaN
# 10     83.0  NaN   NaN       NaN
# 11     83.0  NaN   NaN       NaN
# 13     83.0  NaN   NaN       NaN
# 14     73.0  NaN   NaN       NaN
# 15     74.0  NaN   NaN       NaN
# 16     17.0  NaN   NaN       NaN
# 17     72.0  NaN   NaN       NaN
# 18     21.0  NaN   NaN       NaN
# 19     71.0  NaN   NaN       NaN
# 20     25.0  NaN   NaN       NaN
# 21     23.0  NaN   NaN       NaN
# 22     20.0  NaN   NaN       NaN
# 24     21.0  NaN   NaN       NaN
# 25     82.0  NaN   NaN       NaN
# 26     21.0  NaN   NaN       NaN
# 27     24.0  NaN   NaN       NaN
# 28     74.0  NaN   NaN       NaN
# 29     83.0  NaN   NaN       NaN
# 30     23.0  NaN   NaN       NaN
# 31     76.0  NaN   NaN       NaN
# 32     22.0  NaN   NaN       NaN
# 33     18.0  NaN   NaN       NaN
# 34     79.0  NaN   NaN       NaN
# 35     77.0  NaN   NaN       NaN
# 36     22.0  NaN   NaN       NaN
# 37     26.0  NaN   NaN       NaN
# 38     75.0  NaN   NaN       NaN
# 39     75.0  NaN   NaN       NaN
# 40     79.0  NaN   NaN       NaN
# 41     18.0  NaN   NaN       NaN
# 42     20.0  NaN   NaN       NaN
# 43     80.0  NaN   NaN       NaN
# 44     18.0  NaN   NaN       NaN
# 45     19.0  NaN   NaN       NaN
# 46     21.0  NaN   NaN       NaN
# 47     23.0  NaN   NaN       NaN
# 48     82.0  NaN   NaN       NaN
# 49     25.0  NaN   NaN       NaN
# 50     22.0  NaN   NaN       NaN
# 51     75.0  NaN   NaN       NaN
# 52     81.0  NaN   NaN       NaN
# 53     18.0  NaN   NaN       NaN
# 54     21.0  NaN   NaN       NaN
# 55     24.0  NaN   NaN       NaN
# 57     22.0  NaN   NaN       NaN
# 58     75.0  NaN   NaN       NaN
# 59     20.0  NaN   NaN       NaN
# 60     83.0  NaN   NaN       NaN
# 61     81.0  NaN   NaN       NaN
# 62     18.0  NaN   NaN       NaN
# 63     52.0  NaN   NaN       NaN

# %% [markdown]
# # Read data from other CSV files

# %% [markdown]
# ### Get Users

# %%
users = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/users.csv')

users.head()
# Out:
#    UserID      User  Gender  Registered   Cancelled
# 0       1   Charles    male  2012-12-21         NaN
# 1       2     Pedro    male  2010-08-01  2010-08-08
# 2       3  Caroline  female  2012-10-23  2016-06-07
# 3       4   Brielle  female  2013-07-17         NaN
# 4       5  Benjamin    male  2010-11-25         NaN

# %% [markdown]
# ### Get Sessions

# %%
sessions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/sessions.csv')

sessions.head()
# Out:
#    SessionID SessionDate  UserID
# 0          1  2010-01-05       2
# 1          2  2010-08-01       2
# 2          3  2010-11-25       2
# 3          4  2011-09-21       5
# 4          5  2011-10-19       4

# %% [markdown]
# ### Get Products

# %%
products = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/products.csv')

products.head()
# Out:
#    ProductID Product  Price
# 0          1       A  14.16
# 1          2       B  33.04
# 2          3       C  10.65
# 3          4       D  10.02
# 4          5       E  29.66

# %% [markdown]
# ### Get Transactions

# %%
transactions = pd.read_csv('https://raw.githubusercontent.com/ben519/DataWrangling/master/Data/transactions.csv')

transactions
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 1              2      2011-05-26     3.0          4         1
# 2              3      2011-06-16     3.0          3         1
# 3              4      2012-08-26     1.0          2         3
# 4              5      2013-06-06     2.0          4         1
# 5              6      2013-12-23     2.0          5         6
# 6              7      2013-12-30     3.0          4         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3
# 9             10      2016-05-08     3.0          4         4

# %% [markdown]
# ### 12. Join users to transactions, keeping all rows from transactions and only matching rows from users (left join)

# %%
transactions.merge(users, how='left', on='UserID')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              1      2010-08-21     7.0          2         1       NaN
# 1              2      2011-05-26     3.0          4         1  Caroline
# 2              3      2011-06-16     3.0          3         1  Caroline
# 3              4      2012-08-26     1.0          2         3   Charles
# 4              5      2013-06-06     2.0          4         1     Pedro
# 5              6      2013-12-23     2.0          5         6     Pedro
# 6              7      2013-12-30     3.0          4         1  Caroline
# 7              8      2014-04-24     NaN          2         3       NaN
# 8              9      2015-04-24     7.0          4         3       NaN
# 9             10      2016-05-08     3.0          4         4  Caroline
#
#    Gender  Registered   Cancelled
# 0     NaN         NaN         NaN
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3    male  2012-12-21         NaN
# 4    male  2010-08-01  2010-08-08
# 5    male  2010-08-01  2010-08-08
# 6  female  2012-10-23  2016-06-07
# 7     NaN         NaN         NaN
# 8     NaN         NaN         NaN
# 9  female  2012-10-23  2016-06-07

# %% [markdown]
# ### 13. Which transactions have a UserID not in users? ###

# %%
transactions[~transactions['UserID'].isin(users['UserID'])]
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity
# 0              1      2010-08-21     7.0          2         1
# 7              8      2014-04-24     NaN          2         3
# 8              9      2015-04-24     7.0          4         3

# %% [markdown]
# ### 14. Join users to transactions, keeping only rows from transactions and users that match via UserID (inner join) ###

# %%
transactions.merge(users, how="inner", on='UserID')
# Out:
#    TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0              2      2011-05-26     3.0          4         1  Caroline
# 1              3      2011-06-16     3.0          3         1  Caroline
# 2              7      2013-12-30     3.0          4         1  Caroline
# 3             10      2016-05-08     3.0          4         4  Caroline
# 4              4      2012-08-26     1.0          2         3   Charles
# 5              5      2013-06-06     2.0          4         1     Pedro
# 6              6      2013-12-23     2.0          5         6     Pedro
#
#    Gender  Registered   Cancelled
# 0  female  2012-10-23  2016-06-07
# 1  female  2012-10-23  2016-06-07
# 2  female  2012-10-23  2016-06-07
# 3  female  2012-10-23  2016-06-07
# 4    male  2012-12-21         NaN
# 5    male  2010-08-01  2010-08-08
# 6    male  2010-08-01  2010-08-08

# %% [markdown]
# ### 15. Join users to transactions, displaying all matching rows AND all non-matching rows (full outer join) ###

# %%
transactions.merge(users, how="outer", on='UserID')
# Out:
#     TransactionID TransactionDate  UserID  ProductID  Quantity      User  \
# 0             1.0      2010-08-21     7.0        2.0       1.0       NaN
# 1             9.0      2015-04-24     7.0        4.0       3.0       NaN
# 2             2.0      2011-05-26     3.0        4.0       1.0  Caroline
# 3             3.0      2011-06-16     3.0        3.0       1.0  Caroline
# 4             7.0      2013-12-30     3.0        4.0       1.0  Caroline
# 5            10.0      2016-05-08     3.0        4.0       4.0  Caroline
# 6             4.0      2012-08-26     1.0        2.0       3.0   Charles
# 7             5.0      2013-06-06     2.0        4.0       1.0     Pedro
# 8             6.0      2013-12-23     2.0        5.0       6.0     Pedro
# 9             8.0      2014-04-24     NaN        2.0       3.0       NaN
# 10            NaN             NaN     4.0        NaN       NaN   Brielle
# 11            NaN             NaN     5.0        NaN       NaN  Benjamin
#
#     Gender  Registered   Cancelled
# 0      NaN         NaN         NaN
# 1      NaN         NaN         NaN
# 2   female  2012-10-23  2016-06-07
# 3   female  2012-10-23  2016-06-07
# 4   female  2012-10-23  2016-06-07
# 5   female  2012-10-23  2016-06-07
# 6     male  2012-12-21         NaN
# 7     male  2010-08-01  2010-08-08
# 8     male  2010-08-01  2010-08-08
# 9      NaN         NaN         NaN
# 10  female  2013-07-17         NaN
# 11    male  2010-11-25         NaN

# %% [markdown]
# ### 16. Determine which sessions occurred on the same day each user registered ###

# %%
users.merge(sessions, left_on=['UserID', 'Registered'], right_on=['UserID', 'SessionDate'])
# Out:
#    UserID     User  Gender  Registered   Cancelled  SessionID SessionDate
# 0       2    Pedro    male  2010-08-01  2010-08-08          2  2010-08-01
# 1       4  Brielle  female  2013-07-17         NaN          9  2013-07-17

# %% [markdown]
# ### 17. Build a dataset with every possible (UserID, ProductID) pair (cross join) ###

# %%
users_1 = users
users_1['key'] = 0

products_1 = products
products_1['key'] = 0

pd.merge(users_1, products_1, on='key', how="outer")[['UserID', 'ProductID']]
# Out:
#     UserID  ProductID
# 0        1          1
# 1        1          2
# 2        1          3
# 3        1          4
# 4        1          5
# 5        2          1
# 6        2          2
# 7        2          3
# 8        2          4
# 9        2          5
# 10       3          1
# 11       3          2
# 12       3          3
# 13       3          4
# 14       3          5
# 15       4          1
# 16       4          2
# 17       4          3
# 18       4          4
# 19       4          5
# 20       5          1
# 21       5          2
# 22       5          3
# 23       5          4
# 24       5          5

# %% [markdown]
# ### 18. Determine how much quantity of each product was purchased by each user ###

# %%
users.merge(products, how='outer').merge(transactions, on=['UserID','ProductID'], how="outer").loc[:, ["UserID", "ProductID", "Quantity"]].fillna(0)
# Out:
#     UserID  ProductID  Quantity
# 0      1.0          1       0.0
# 1      1.0          2       3.0
# 2      1.0          3       0.0
# 3      1.0          4       0.0
# 4      1.0          5       0.0
# 5      2.0          1       0.0
# 6      2.0          2       0.0
# 7      2.0          3       0.0
# 8      2.0          4       1.0
# 9      2.0          5       6.0
# 10     3.0          1       0.0
# 11     3.0          2       0.0
# 12     3.0          3       1.0
# 13     3.0          4       1.0
# 14     3.0          4       1.0
# 15     3.0          4       4.0
# 16     3.0          5       0.0
# 17     4.0          1       0.0
# 18     4.0          2       0.0
# 19     4.0          3       0.0
# 20     4.0          4       0.0
# 21     4.0          5       0.0
# 22     5.0          1       0.0
# 23     5.0          2       0.0
# 24     5.0          3       0.0
# 25     5.0          4       0.0
# 26     5.0          5       0.0
# 27     7.0          2       1.0
# 28     0.0          2       3.0
# 29     7.0          4       3.0

# %% [markdown]
# ### 19. For each user, get each possible pair of pair transactions (TransactionID1,TransacationID2) ###

# %%
pd.merge(transactions, transactions, on='UserID')
# Out:
#     TransactionID_x TransactionDate_x  UserID  ProductID_x  Quantity_x  \
# 0                 1        2010-08-21     7.0            2           1
# 1                 1        2010-08-21     7.0            2           1
# 2                 9        2015-04-24     7.0            4           3
# 3                 9        2015-04-24     7.0            4           3
# 4                 2        2011-05-26     3.0            4           1
# 5                 2        2011-05-26     3.0            4           1
# 6                 2        2011-05-26     3.0            4           1
# 7                 2        2011-05-26     3.0            4           1
# 8                 3        2011-06-16     3.0            3           1
# 9                 3        2011-06-16     3.0            3           1
# 10                3        2011-06-16     3.0            3           1
# 11                3        2011-06-16     3.0            3           1
# 12                7        2013-12-30     3.0            4           1
# 13                7        2013-12-30     3.0            4           1
# 14                7        2013-12-30     3.0            4           1
# 15                7        2013-12-30     3.0            4           1
# 16               10        2016-05-08     3.0            4           4
# 17               10        2016-05-08     3.0            4           4
# 18               10        2016-05-08     3.0            4           4
# 19               10        2016-05-08     3.0            4           4
# 20                4        2012-08-26     1.0            2           3
# 21                5        2013-06-06     2.0            4           1
# 22                5        2013-06-06     2.0            4           1
# 23                6        2013-12-23     2.0            5           6
# 24                6        2013-12-23     2.0            5           6
# 25                8        2014-04-24     NaN            2           3
#
#     TransactionID_y TransactionDate_y  ProductID_y  Quantity_y
# 0                 1        2010-08-21            2           1
# 1                 9        2015-04-24            4           3
# 2                 1        2010-08-21            2           1
# 3                 9        2015-04-24            4           3
# 4                 2        2011-05-26            4           1
# 5                 3        2011-06-16            3           1
# 6                 7        2013-12-30            4           1
# 7                10        2016-05-08            4           4
# 8                 2        2011-05-26            4           1
# 9                 3        2011-06-16            3           1
# 10                7        2013-12-30            4           1
# 11               10        2016-05-08            4           4
# 12                2        2011-05-26            4           1
# 13                3        2011-06-16            3           1
# 14                7        2013-12-30            4           1
# 15               10        2016-05-08            4           4
# 16                2        2011-05-26            4           1
# 17                3        2011-06-16            3           1
# 18                7        2013-12-30            4           1
# 19               10        2016-05-08            4           4
# 20                4        2012-08-26            2           3
# 21                5        2013-06-06            4           1
# 22                6        2013-12-23            5           6
# 23                5        2013-06-06            4           1
# 24                6        2013-12-23            5           6
# 25                8        2014-04-24            2           3

# %% [markdown]
# ### 20. Join each user to his/her first occuring transaction in the transactions table ###

# %%
first_transactions = transactions[transactions['UserID'].isin(users['UserID'])].groupby('UserID').first().reset_index()

data = users.merge(first_transactions, on='UserID', how="outer")

data
# Out:
#    UserID      User  Gender  Registered   Cancelled  key  TransactionID  \
# 0       1   Charles    male  2012-12-21         NaN    0            4.0
# 1       2     Pedro    male  2010-08-01  2010-08-08    0            5.0
# 2       3  Caroline  female  2012-10-23  2016-06-07    0            2.0
# 3       4   Brielle  female  2013-07-17         NaN    0            NaN
# 4       5  Benjamin    male  2010-11-25         NaN    0            NaN
#
#   TransactionDate  ProductID  Quantity
# 0      2012-08-26        2.0       3.0
# 1      2013-06-06        4.0       1.0
# 2      2011-05-26        4.0       1.0
# 3             NaN        NaN       NaN
# 4             NaN        NaN       NaN
